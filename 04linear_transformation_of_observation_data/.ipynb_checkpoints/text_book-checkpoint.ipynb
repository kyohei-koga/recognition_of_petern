# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
X = df[[2,3,4]]

# %%
#花弁の長さと幅の平均値
X.describe()
# Out:
#                 2           3
# count  150.000000  150.000000
# mean     3.758667    1.198667
# std      1.764420    0.763161
# min      1.000000    0.100000
# 25%      1.600000    0.300000
# 50%      4.350000    1.300000
# 75%      5.100000    1.800000
# max      6.900000    2.500000

# %%
np.cov(X[[2,3]],rowvar=0,bias=0)#bias=1：標本分散、bias=0：不偏分散
# Out:
# array([[ 3.11317942,  1.29638747],
#        [ 1.29638747,  0.58241432]])

# %%
X[4].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.scatter(X[X[4]=='Iris-setosa'][2],X[X[4]=='Iris-setosa'][3],label='setosa',c='b')
plt.scatter(X[X[4]=='Iris-versicolor'][2],X[X[4]=='Iris-versicolor'][3],label='versicolor',c='r')
plt.scatter(X[X[4]=='Iris-virginica'][2],X[X[4]=='Iris-virginica'][3],label='varginica',c='g')
plt.legend(loc='upper left')

# %%
#標準化
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X[[2,3]].values)
X_std = sc.transform(X[[2,3]])

# %%
plt.scatter(X_std[(X[4]=='Iris-setosa').values][:,0],X_std[(X[4]=='Iris-setosa').values][:,1],label='setosa',c='b')
plt.scatter(X_std[(X[4]=='Iris-versicolor').values][:,0],X_std[(X[4]=='Iris-versicolor').values][:,1],label='versicolor',c='r')
plt.scatter(X_std[(X[4]=='Iris-virginica').values][:,0],X_std[(X[4]=='Iris-virginica').values][:,1],label='varginica',c='g')
plt.legend(loc='upper left')

# %%
#共分散行列の固有値及び、固有ベクトル
la,v = np.linalg.eig(np.cov(X[[2,3]],rowvar=0,bias=0))

# %%
la
# Out:
# array([ 3.65937449,  0.03621925])

# %%
v
# Out:
# array([[ 0.92154695, -0.38826694],
#        [ 0.38826694,  0.92154695]])

# %%
#無相関化
X_noncor = np.dot(X[[2,3]],v)

# %%
plt.scatter(X_noncor[(X[4]=='Iris-setosa').values][:,0],X_noncor[(X[4]=='Iris-setosa').values][:,1],label='setosa',c='b')
plt.scatter(X_noncor[(X[4]=='Iris-versicolor').values][:,0],X_noncor[(X[4]=='Iris-versicolor').values][:,1],label='versicolor',c='r')
plt.scatter(X_noncor[(X[4]=='Iris-virginica').values][:,0],X_noncor[(X[4]=='Iris-virginica').values][:,1],label='varginica',c='g')
plt.ylim((-3,3))
plt.legend(loc='upper left')

# %%
#無相関化したあとの、共分散行列
np.cov(X_noncor,rowvar=0,bias=0)
# Out:
# array([[  3.65937449e+00,  -1.60945083e-16],
#        [ -1.60945083e-16,   3.62192472e-02]])

# %%
data_pima = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data',header=None)

# %%
data_pima.columns = ['npreg','glu','bp','skin','ins','bmi','ped','age','type']

# %%
data_pima.shape
# Out:
# (768, 9)

# %%
#前処理
data_pima = data_pima[data_pima.glu>0]
data_pima = data_pima[data_pima.bmi>0]

# %%
plt.scatter(data_pima[data_pima['type']==1].glu,data_pima[data_pima['type']==1].bmi,marker='^',c='b',alpha=0.6,label='yes')
plt.scatter(data_pima[data_pima['type']==0].glu,data_pima[data_pima['type']==0].bmi,marker='o',c='r',alpha=0.6,label='no')
plt.xlabel('glu')
plt.ylabel('bmi')
plt.legend(loc='upper right')

# %%
#教科書（4.32）を計算し、図示する。
class1 = data_pima[data_pima['type']==1][['glu','bmi']].as_matrix()
class0 = data_pima[data_pima['type']==0][['glu','bmi']].as_matrix()

# %%
mu1 = np.array([class1.mean(axis=0)])
mu0 = np.array([class0.mean(axis=0)])

# %%
P1 = class1.shape[0] / float(data_pima.shape[0])
P0 = class0.shape[0] / float(data_pima.shape[0])

# %%
#covから
#http://decompose.hatenablog.com/entry/2016/04/10/060000
cov1 = np.cov(class1,rowvar=0)
cov0 = np.cov(class0,rowvar=0)

# %%
#識別関数の係数の計算 i=1,j=0
S = np.linalg.inv(cov1) - np.linalg.inv(cov0)
c = np.dot(mu0,np.linalg.inv(cov0)) - np.dot(mu1,np.linalg.inv(cov1))
F = np.dot(np.dot(mu1,np.linalg.inv(cov1)),mu1.T) - np.dot(np.dot(mu0,np.linalg.inv(cov0)),mu0.T) + np.log(np.linalg.det(cov0)/np.linalg.det(cov1)) - 2*np.log(P1/P0)

# %%
#識別関数
def identification(x,S,c,F):
    return np.dot(np.dot(x,S),x.T) + 2 * (np.dot(c,x.T)) + F

# %%
x = np.arange(50,210,1)
y = np.arange(15,50,1)
X,Y=np.meshgrid(x,y)
#Xnew Ynewは、ベクトルに直しています。
Xnew = X.reshape(1,35*160)
Ynew = Y.reshape(1,35*160)
#XYの各列に、XY平面上の点が格納されているイメージです。
XY = np.array([Xnew[0,:],Ynew[0,:]])

# %%
z = []
for i in range(a.shape[0]):
    z.append(identification(a[i],S,c,F))

# %%
(np.array(z).reshape(X.shape)==0).sum()
# Out:
# 0

# %%
X.shape
# Out:
# (35, 160)

# %%
plt.contour(X,Y,np.array(z).reshape(X.shape))
plt.scatter(data_pima[data_pima['type']==1].glu,data_pima[data_pima['type']==1].bmi,marker='^',c='b',alpha=0.6,label='yes')
plt.scatter(data_pima[data_pima['type']==0].glu,data_pima[data_pima['type']==0].bmi,marker='o',c='r',alpha=0.6,label='no')
plt.xlabel('glu')
plt.ylabel('bmi')
plt.legend(loc='upper right')

# %%
f = np.zeros(len(Xnew[0,:])) #fの箱を作っておきます。
for i in range(len(Xnew[0,:])):
    f[i] = XY[:,i].transpose().dot(S).dot(XY[:,i]) + 2 * c.dot(XY[:,i]) + F
Z = np.reshape(f,(35,160))

# %%
cont = plt.contour(X,Y,Z,levels=[-2,0,2])
cont.clabel(fmt='%1.1f', fontsize=14)
plt.scatter(data_pima[data_pima['type']==1].glu,data_pima[data_pima['type']==1].bmi,marker='^',c='b',alpha=0.6,label='yes')
plt.scatter(data_pima[data_pima['type']==0].glu,data_pima[data_pima['type']==0].bmi,marker='o',c='r',alpha=0.6,label='no')
plt.xlabel('glu')
plt.ylabel('bmi')
plt.legend(loc='upper right')
